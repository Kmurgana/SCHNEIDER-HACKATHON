# %% [markdown]
# # **<span style="color:#00C853;">Schneider Electric Hackathon</span>**

# %% [markdown]
# The EU contributes 18% of total global warming gas emissions; However, it is increasingly determined to take the lead in the fight against climate change. That is why it has set itself the goal of reaching zero carbon emissions by 2050.
#
# To this end, it has put in place a wealth of resources to help achieve this goal over the next few years, and it will need your help to do so.
#
# **Task**
#
# Create a model to predict the pollutant variable in the test_x dataset.
# Create a presentation (MAX 4 slides) explaining what you have done and why you have done it.. (Example: Download example )

# %% [markdown]
# **Roadmap**
#
# Antes de lanzarnos de lleno a la programación, deberíamos trazar una breve guía para mantenernos en el camino. Los siguientes pasos constituyen la base de cualquier flujo de trabajo de aprendizaje automático una vez que tenemos un problema y un modelo en mente:
#
# * 1) Plantear la pregunta y determinar los datos necesarios
# * 2) Adquirir los datos en un formato accesible
# * 3) Identificar y corregir los puntos de datos/anomalías que faltan, según sea necesario
# * 4) Preparar los datos para el modelo de aprendizaje automático
# * 5) Entrenar el modelo con los datos de entrenamiento
# * 6) Hacer predicciones con los datos de prueba
# * 7) Comparar las predicciones con los objetivos conocidos del conjunto de pruebas y calcular las métricas de rendimiento
# * 8) Si el rendimiento no es satisfactorio, ajustar el modelo, adquiera más datos o pruebe otra técnica de modelización.
# * 9) Interpretar el modelo y comunicar los resultados de forma visual y numérica

# %% [markdown]
# ### ✅1) Planteando la pregunta ❓
#
# El ejercicio consiste en conseguir un modelo predictivo capaz de clasificar el tipo de contaminante generado en diferentes complejo, para lo cual, el **objetivo** es que dicho modelo tenga una presición elevada.

# %% [markdown]
# ### ✅ 2) Adquiriendo los datos 🔍

# %% [markdown]
# #### Importamos las librerías necesarias para comenzar.
# * Para manejo de datasets, la librería por defecto más usada es **PANDAS**.
# * Necesitamos leer datos de una API json, elegimnos: **requests** para generar solicitudes y **json** para leer los datos en formato java script.
# * Necesitamos leer PDF,  la librería que utilizaremos será : **pdfx**

# %%
import pandas as pd
import numpy as np
import pdfx
import requests
import json

# %% [markdown]
# ### 2.1 Leyendo datos desde CSV

# %% [markdown]
# #### 2.1.1 Leyendo primer dato CSV

# %%
#1. Con pandas, importamos el dataset 1
train1 = pd.read_csv("../3- Schneider Hackathon/Datasets/train1.csv", sep=',')

# %%
#2. Observamos el encabezado y dimensiones
train1.head()
# Out:
#   countryName                  eprtrSectorName  \
# 0     Germany                 Mineral industry
# 1       Italy                 Mineral industry
# 2       Spain  Waste and wastewater management
# 3     Czechia                    Energy sector
# 4     Finland  Waste and wastewater management
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0  Installations for the production of cement cli...
# 1  Installations for the production of cement cli...
# 2  Landfills (excluding landfills of inert waste ...
# 3  Thermal power stations and other combustion in...
# 4                 Urban waste-water treatment plants
#
#                                    FacilityInspireID  \
# 0  https://registry.gdi-de.org/id/de.ni.mu/062217...
# 1                         IT.CAED/240602021.FACILITY
# 2                         ES.CAED/001966000.FACILITY
# 3                    CZ.MZP.U422/CZ34736841.FACILITY
# 4  http://paikkatiedot.fi/so/1002031/pf/Productio...
#
#                                         facilityName                  City  \
# 0               Holcim (Deutschland) GmbH Werk Höver                Sehnde
# 1               Stabilimento di Tavernola Bergamasca  TAVERNOLA BERGAMASCA
# 2                  COMPLEJO MEDIOAMBIENTAL DE ZURITA    PUERTO DEL ROSARIO
# 3                                Elektrárny Prunéřov                 Kadaň
# 4  TAMPEREEN VESI LIIKELAITOS, VIINIKANLAHDEN JÄT...               Tampere
#
#   targetRelease              pollutant  reportingYear  MONTH  ...  CONTINENT  \
# 0           AIR   Carbon dioxide (CO2)           2015     10  ...     EUROPE
# 1           AIR  Nitrogen oxides (NOX)           2018      9  ...     EUROPE
# 2           AIR          Methane (CH4)           2019      2  ...     EUROPE
# 3           AIR  Nitrogen oxides (NOX)           2012      8  ...     EUROPE
# 4           AIR          Methane (CH4)           2018     12  ...     EUROPE
#
#   max_wind_speed  avg_wind_speed  min_wind_speed   max_temp   avg_temp  \
# 0      15.118767       14.312541       21.419106   2.864895   4.924169
# 1      19.661550       19.368166       21.756389   5.462839   7.864403
# 2      12.729453       14.701985       17.103930   1.511201   4.233438
# 3      11.856417       16.122584       17.537184  10.970301  10.298348
# 4      17.111930       20.201604       21.536012  11.772039  11.344078
#
#     min_temp  DAY WITH FOGS     REPORTER NAME  \
# 0   9.688206              2  Mr. Jacob Ortega
# 1  12.023521              1    Ashlee Serrano
# 2   8.632193              2      Vincent Kemp
# 3  15.179215              0        Carol Gray
# 4  16.039004              2        Blake Ford
#
#                             CITY ID
# 0  7cdb5e74adcb2ffaa21c1b61395a984f
# 1  cd1dbabbdba230b828c657a9b19a8963
# 2  5011e3fa1436d15b34f1287f312fbada
# 3  37a6d7a71c4f7c2469e4f01b70dd90c2
# 4  471fe554e1c62d1b01cc8e4e5076c61a
#
# [5 rows x 21 columns]

# %%
train1.shape
# Out:
# (18563, 21)

# %%
train1.columns
# Out:
# Index(['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
#        'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
#        'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
#        'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
#        'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID'],
#       dtype='object')

# %%
data_types = train1.dtypes
data_types
# Out:
# countryName                      object
# eprtrSectorName                  object
# EPRTRAnnexIMainActivityLabel     object
# FacilityInspireID                object
# facilityName                     object
# City                             object
# targetRelease                    object
# pollutant                        object
# reportingYear                     int64
# MONTH                             int64
# DAY                               int64
# CONTINENT                        object
# max_wind_speed                  float64
# avg_wind_speed                  float64
# min_wind_speed                  float64
# max_temp                        float64
# avg_temp                        float64
# min_temp                        float64
# DAY WITH FOGS                     int64
# REPORTER NAME                    object
# CITY ID                          object
# dtype: object

# %% [markdown]
# #### 2.1.2 Leyendo segundo dato CSV

# %%
#1. Con pandas, importamos el dataset 2
# Colocamos este dataset tiene como separador ; en vez de , como el anterior, por lo que los especificamos.
train2 = pd.read_csv("../3- Schneider Hackathon/Datasets/train2.csv", sep=';')

# %%
#2. Observamos el encabezado y dimensiones
train2.head(20)
# Out:
#        countryName                                 eprtrSectorName  \
# 0          Germany                 Waste and wastewater management
# 1           France                                   Energy sector
# 2           France                                   Energy sector
# 3          Germany                 Waste and wastewater management
# 4          Estonia                                   Energy sector
# 5           Sweden                                   Energy sector
# 6      Switzerland                 Waste and wastewater management
# 7           Sweden                 Waste and wastewater management
# 8       Luxembourg             Production and processing of metals
# 9            Spain                 Waste and wastewater management
# 10         Germany        Paper and wood production and processing
# 11          France                 Waste and wastewater management
# 12  United Kingdom                                   Energy sector
# 13          France                                Mineral industry
# 14         Ireland                 Waste and wastewater management
# 15         Ireland  Intensive livestock production and aquaculture
# 16           Italy                                   Energy sector
# 17          Poland                                   Energy sector
# 18  United Kingdom                                   Energy sector
# 19         Austria                                Mineral industry
#
#                          EPRTRAnnexIMainActivityLabel  \
# 0   Installations for the incineration of non-haza...
# 1   Thermal power stations and other combustion in...
# 2   Thermal power stations and other combustion in...
# 3   Landfills (excluding landfills of inert waste ...
# 4     Installations for gasification and liquefaction
# 5   Thermal power stations and other combustion in...
# 6   Installations for the incineration of non-haza...
# 7   Landfills (excluding landfills of inert waste ...
# 8   Installations for the processing of ferrous me...
# 9   Landfills (excluding landfills of inert waste ...
# 10  Industrial plants for the production of paper ...
# 11  Installations for the incineration of non-haza...
# 12  Thermal power stations and other combustion in...
# 13  Installations for the production of cement cli...
# 14  Installations for the disposal of non-hazardou...
# 15  Installations for the intensive rearing of pig...
# 16  Thermal power stations and other combustion in...
# 17  Thermal power stations and other combustion in...
# 18  Thermal power stations and other combustion in...
# 19  Installations for the manufacture of glass, in...
#
#                                     FacilityInspireID  \
# 0   https://registry.gdi-de.org/id/de.hh/pf.bube-e...
# 1                                FR.EEA/6288.FACILITY
# 2                              FR.CAED/12066.FACILITY
# 3   https://registry.gdi-de.org/id/de.nw.inspire.p...
# 4                             EE.KAUR.TTR/76.FACILITY
# 5                           SE.CAED/10020920.Facility
# 6                          CH.CAED/000000227.Facility
# 7                           SE.CAED/10020071.Facility
# 8                          LU.CAED/000029000.FACILITY
# 9                          ES.CAED/004958000.FACILITY
# 10  https://registry.gdi-de.org/id/de.rp.inspire.p...
# 11                             FR.CAED/12722.FACILITY
# 12           UK.CAED/BEISOffsh-Alba-Northern.FACILITY
# 13                              FR.CAED/5217.FACILITY
# 14                             IE.CAED/W0002.FACILITY
# 15                             IE.CAED/P0961.FACILITY
# 16                         IT.CAED/810301001.FACILITY
# 17                           PL.MŚ/000000267.FACILITY
# 18         UK.CAED/BEISOffsh-Cormorant-Alpha.FACILITY
# 19                     AT.CAED/9008390510124.FACILITY
#
#                                          facilityName  \
# 0   MVR Müllverwertung Rugenberger Damm GmbH & Co. KG
# 1                             SOCIETE DE COGENERATION
# 2                                    CPCU ST-OUEN III
# 3          Deponie Haus Forst REMONDIS GmbH Rheinland
# 4   Enefit Energiatootmine AS, Auvere põlevkiviõli...
# 5                            Karlskoga kraftvärmeverk
# 6                                     TRIDEL Lausanne
# 7   SUEZ Recycling AB, Rödjorna, Härlingstorp 4:1 ...
# 8                             ArcelorMittal Dudelange
# 9   COMPLEXO MEDIOAMBIENTAL DE TRATAMENTO DE RSU E...
# 10                  Nolte Holzwerkstoff GmbH & Co. KG
# 11                                            ARCANTE
# 12                                      Alba Northern
# 13                                 VICAT SAINT-EGRÈVE
# 14                          Ballyguyroe Landfill Site
# 15                  Hermitage Pedigree Pigs (Clifden)
# 16                                         SET S.p.A.
# 17             Elektrociepłownia Mielec Spółka z o.o.
# 18                                    Cormorant Alpha
# 19                             Vetropack Austria GmbH
#
#                               City targetRelease              pollutant  \
# 0                          Hamburg           AIR  Nitrogen oxides (NOX)
# 1                           TAVAUX           AIR  Nitrogen oxides (NOX)
# 2                       SAINT-OUEN           AIR   Carbon dioxide (CO2)
# 3                           Kerpen           AIR          Methane (CH4)
# 4   Auvere küla, Narva-Jõesuu linn           AIR   Carbon dioxide (CO2)
# 5                        KARLSKOGA           AIR   Carbon dioxide (CO2)
# 6                         Lausanne           AIR   Carbon dioxide (CO2)
# 7                            SKARA           AIR          Methane (CH4)
# 8                        Dudelange           AIR  Nitrogen oxides (NOX)
# 9                           SERVIA           AIR          Methane (CH4)
# 10                     Germersheim           AIR  Nitrogen oxides (NOX)
# 11                           BLOIS           AIR  Nitrogen oxides (NOX)
# 12                              --           AIR          Methane (CH4)
# 13                    SAINT-EGREVE           AIR  Nitrogen oxides (NOX)
# 14                            Cork           AIR          Methane (CH4)
# 15                        Kilkenny           AIR          Methane (CH4)
# 16                        TEVEROLA           AIR  Nitrogen oxides (NOX)
# 17                          Mielec           AIR   Carbon dioxide (CO2)
# 18                              --           AIR   Carbon dioxide (CO2)
# 19                        Pöchlarn           AIR  Nitrogen oxides (NOX)
#
#     reportingYear  MONTH  ...  CONTINENT max_wind_speed  avg_wind_speed  \
# 0            2012      4  ...     EUROPE      13.006440       17.328013
# 1            2007      3  ...     EUROPE      12.601338       16.415961
# 2            2008     11  ...     EUROPE      17.051488       18.558361
# 3            2009      2  ...     EUROPE       9.345776       14.584978
# 4            2016      7  ...     EUROPE      17.122838       18.382589
# 5            2019     10  ...     EUROPE      17.063911       20.519818
# 6            2013      6  ...     EUROPE      12.605711       16.682035
# 7            2011      2  ...     EUROPE      13.973565       15.851127
# 8            2010     11  ...     EUROPE      16.068441       17.179704
# 9            2012      2  ...     EUROPE      18.081017       21.514301
# 10           2013      4  ...     EUROPE      20.138702       21.495448
# 11           2019     12  ...     EUROPE      15.177382       16.822651
# 12           2014      1  ...     EUROPE      13.514982       14.151348
# 13           2018      6  ...     EUROPE      18.608203       18.363855
# 14           2014     10  ...     EUROPE      15.890035       15.806178
# 15           2017      8  ...     EUROPE      17.874728       17.075266
# 16           2018      2  ...     EUROPE      14.004958       18.559040
# 17           2015      3  ...     EUROPE      19.233492       21.188434
# 18           2011      5  ...     EUROPE      14.380567       15.408289
# 19           2015      3  ...     EUROPE      17.084213       18.070867
#
#     min_wind_speed   max_temp   avg_temp   min_temp  DAY WITH FOGS  \
# 0        22.819874  13.642167  13.524782  15.210716              0
# 1        20.870744  12.425496  11.640683  14.170232              1
# 2        22.729832  10.676109  12.530537  14.036677              1
# 3        22.153539   1.158088   1.424305   4.768707              1
# 4        20.621925   8.620337   8.336314  12.852514              0
# 5        23.084057  11.375806  12.972962  16.259667              2
# 6        18.086070  10.801379  13.061859  15.265277              1
# 7        17.580519   8.870747   9.089316  10.427751              2
# 8        22.614642   4.288972   5.584760   9.199652              0
# 9        26.428684   6.271424   8.142678  11.357042              2
# 10       25.882598  11.251684  12.668646  17.563548              1
# 11       22.703258   3.757191   5.439692   7.880385              0
# 12       15.797800   8.885173   9.251095  12.229604             11
# 13       20.910165   9.014741  11.337456  12.877451              1
# 14       22.344941  -2.485109  -0.045144   2.067939              2
# 15       23.964024   6.321349   7.088445  10.761465              0
# 16       22.886056   2.550828   4.803000   6.588258              2
# 17       26.273822   7.676274   9.766439  12.728469              2
# 18       18.077208  15.614832  16.228755  18.119302              3
# 19       21.596108  17.698522  16.789768  18.244463              0
#
#        REPORTER NAME                           CITY ID
# 0      Teresa Martin  35d7df6ed3d93be2927d14acc5f1fc9a
# 1      Teresa Monroe  8079579bf1d5379ea893be33dbb997d5
# 2      Brian Johnson  38fde98415bd374755bb341af3241c4f
# 3      David Jackson  8b73a54f4cb8ff07dd3e956bfa42b196
# 4       Holly Graves  cffe5169a23e2951963dc5e5da3fcd97
# 5       Karen Torres  8f2e9927f13253155730c49768a0f4f4
# 6      Laura Meza MD  2f4d156f29b46c9add9d9337453822fc
# 7        Darryl Shaw  29273739379051e4f9bf9e0acf7e44bb
# 8       Gary Sanders  da590dcc8795f77b650876ad6d39dc58
# 9       Trevor Smith  6d63b2d71bf5749713d69d8b18800669
# 10      Devon Martin  3cbee5e6f5f0f5128af2c9f67b9bae00
# 11     Brandi Warren  794fbc77cf5a0a7414acd5874bdcccc9
# 12     Albert Martin  cfab1ba8c67c7c838db98d666f02a132
# 13       David Perez  8b49497917d03000e38b531ed0df1343
# 14     Bethany Walsh  002c887b8369e59e6f58a5d06a8d0817
# 15       Anita Chase  4ed2a5a94470a32a87a57feda71dd8af
# 16  Katherine Durham  b6f72e8a5ec2a9f632c7f99e9995347e
# 17   Catherine Estes  0d079885501cda42caad99c88f0b571e
# 18        Jean Kelly  cfab1ba8c67c7c838db98d666f02a132
# 19     Sarah Francis  a90ffc112097df7f976e4228f6052994
#
# [20 rows x 21 columns]

# %%
train2.shape
# Out:
# (18564, 21)

# %%
train2.columns
# Out:
# Index(['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
#        'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
#        'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
#        'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
#        'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID'],
#       dtype='object')

# %%
data_types = train2.dtypes
data_types
# Out:
# countryName                      object
# eprtrSectorName                  object
# EPRTRAnnexIMainActivityLabel     object
# FacilityInspireID                object
# facilityName                     object
# City                             object
# targetRelease                    object
# pollutant                        object
# reportingYear                     int64
# MONTH                             int64
# DAY                               int64
# CONTINENT                        object
# max_wind_speed                  float64
# avg_wind_speed                  float64
# min_wind_speed                  float64
# max_temp                        float64
# avg_temp                        float64
# min_temp                        float64
# DAY WITH FOGS                     int64
# REPORTER NAME                    object
# CITY ID                          object
# dtype: object

# %% [markdown]
# ### 2.2.1 Obteniendo datos desde API json

# %% [markdown]
# #### 2.2.1.1 Obteniendo el primer dato json.

# %%
import json

# %%
train3 = pd.read_json('http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/first')

# %%
train3.head()
# Out:
#                                    CITY ID CONTINENT                 City  \
# 0  47068  4c325d62c064477ef17b4c6e4437e121    EUROPE  Europoort Rotterdam
# 1  32952  f5e609e7095f91cc8ce9ed6d8e774a0d    EUROPE                 RION
# 2  72375  cfab1ba8c67c7c838db98d666f02a132    EUROPE                   --
# 3  40702  95b4e51f7b662598134e1eb956407c74    EUROPE             DRIZZONA
# 4  29884  f4433be3b1bfaeeb0633eb65d04b1325    EUROPE                Lünen
#
#    DAY  DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0    2              1                        4(a)
# 1    3              2                        3(c)
# 2    1             12                        1(c)
# 3   17              1                        7(a)
# 4    6              0                        5(a)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  \
# 0  Chemical installations for the production on a...                4
# 1  Installations for the production of cement cli...                3
# 2  Thermal power stations and other combustion in...                1
# 3  Installations for the intensive rearing of pou...                7
# 4  Installations for the recovery or disposal of ...                5
#
#                                    FacilityInspireID  ...     countryName  \
# 0                         NL.RIVM/000019070.FACILITY  ...     Netherlands
# 1                            EL.CAED/100075.FACILITY  ...          Greece
# 2         UK.CAED/BEISOffsh-Cormorant-Alpha.FACILITY  ...  United Kingdom
# 3                         IT.CAED/260342003.FACILITY  ...           Italy
# 4  https://registry.gdi-de.org/id/de.nw.inspire.p...  ...         Germany
#
#                                   eprtrSectorName  \
# 0                               Chemical industry
# 1                                Mineral industry
# 2                                   Energy sector
# 3  Intensive livestock production and aquaculture
# 4                 Waste and wastewater management
#
#                                         facilityName   max_temp  \
# 0                        Indorama Ventures Europe BV  13.256816
# 1                  TITAN CEMENT S.A. - DREPANO PLANT   4.528859
# 2                                    Cormorant Alpha  10.669133
# 3  SOCIETA' AGRICOLA SPARAVALLE DI FERRARI GIUSEP...   7.095682
# 4                       Biomassekraftwerk Lünen GmbH   9.886774
#
#   max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0      11.019329  14.696895      20.899762   Carbon dioxide (CO2)
# 1      14.512395   9.219003      23.243403  Nitrogen oxides (NOX)
# 2      20.262171  14.715465      23.956529  Nitrogen oxides (NOX)
# 3      18.283547  13.582024      26.696266          Methane (CH4)
# 4      13.759408  14.006226      24.768933   Carbon dioxide (CO2)
#
#    reportingYear  targetRelease
# 0           2020            AIR
# 1           2019            AIR
# 2           2009            AIR
# 3           2014            AIR
# 4           2015            AIR
#
# [5 rows x 24 columns]

# %%
train3.shape
# Out:
# (9500, 24)

# %%
train3.columns
# Out:
# Index(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#        'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#        'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#        'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#        'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#        'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#       dtype='object')

# %%
data_types = train3.dtypes
data_types
# Out:
#                                   int64
# CITY ID                          object
# CONTINENT                        object
# City                             object
# DAY                               int64
# DAY WITH FOGS                     int64
# EPRTRAnnexIMainActivityCode      object
# EPRTRAnnexIMainActivityLabel     object
# EPRTRSectorCode                   int64
# FacilityInspireID                object
# MONTH                             int64
# REPORTER NAME                    object
# avg_temp                        float64
# avg_wind_speed                  float64
# countryName                      object
# eprtrSectorName                  object
# facilityName                     object
# max_temp                        float64
# max_wind_speed                  float64
# min_temp                        float64
# min_wind_speed                  float64
# pollutant                        object
# reportingYear                     int64
# targetRelease                    object
# dtype: object

# %% [markdown]
# #### 2.2.1.2 Obteniendo el segundo dato json.

# %%
train4 = pd.read_json('http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/second')

# %%
train4.shape
# Out:
# (9500, 24)

# %%
train4.columns
# Out:
# Index(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#        'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#        'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#        'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#        'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#        'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#       dtype='object')

# %%
data_types = train4.dtypes
data_types
# Out:
#                                   int64
# CITY ID                          object
# CONTINENT                        object
# City                             object
# DAY                               int64
# DAY WITH FOGS                     int64
# EPRTRAnnexIMainActivityCode      object
# EPRTRAnnexIMainActivityLabel     object
# EPRTRSectorCode                   int64
# FacilityInspireID                object
# MONTH                             int64
# REPORTER NAME                    object
# avg_temp                        float64
# avg_wind_speed                  float64
# countryName                      object
# eprtrSectorName                  object
# facilityName                     object
# max_temp                        float64
# max_wind_speed                  float64
# min_temp                        float64
# min_wind_speed                  float64
# pollutant                        object
# reportingYear                     int64
# targetRelease                    object
# dtype: object

# %% [markdown]
# #### 2.2.1.3 Obteniendo el tercer dato json.

# %%
train5 = pd.read_json('http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/third')

# %%
train5.head()
# Out:
#                                    CITY ID CONTINENT       City  DAY  \
# 0  41175  7951666b94e0f0891e0c66b2381fca55    EUROPE     TORINO   24
# 1  49299  33c89df2492e8d3efda719c849b530ea    EUROPE       Łódź    4
# 2  34879  4a8b9d98f65af3a29bbf298d8536c142    EUROPE  Tipperary   18
# 3  16905  e38f45f4d669e9f69fa97bfe049ceed6    EUROPE      REIMS   27
# 4  75675  fb960490e42477cbfdcd6bab1793f31e    EUROPE     Hexham   28
#
#    DAY WITH FOGS EPRTRAnnexIMainActivityCode  \
# 0              1                        1(c)
# 1              0                        1(c)
# 2              0                    7(a)(ii)
# 3              0                        3(e)
# 4              2                        6(b)
#
#                         EPRTRAnnexIMainActivityLabel  EPRTRSectorCode  \
# 0  Thermal power stations and other combustion in...                1
# 1  Thermal power stations and other combustion in...                1
# 2  Installations for the intensive rearing of pig...                7
# 3  Installations for the manufacture of glass, in...                3
# 4  Industrial plants for the production of paper ...                6
#
#             FacilityInspireID  ...     countryName  \
# 0  IT.CAED/101511001.FACILITY  ...           Italy
# 1        PL.EEA/1321.FACILITY  ...          Poland
# 2      IE.CAED/P0489.FACILITY  ...         Ireland
# 3       FR.CAED/3453.FACILITY  ...          France
# 4   UK.LAED/E375_434.FACILITY  ...  United Kingdom
#
#                                   eprtrSectorName  \
# 0                                   Energy sector
# 1                                   Energy sector
# 2  Intensive livestock production and aquaculture
# 3                                Mineral industry
# 4        Paper and wood production and processing
#
#                                         facilityName   max_temp  \
# 0                                Iren Energia S.p.A.   7.367005
# 1            Dalkia Łódź S.A. Elektrociepłownia nr 3  12.764269
# 2  Glen of Aherlow Pig Producers Co-Op Society Li...   9.278435
# 3                      OI MANUFACTURING FRANCE REIMS  12.132210
# 4                                 EGGER (UK) LIMITED   3.376109
#
#   max_wind_speed   min_temp min_wind_speed              pollutant  \
# 0      15.892429  12.571580      20.467596  Nitrogen oxides (NOX)
# 1      14.168742  19.081248      25.439515   Carbon dioxide (CO2)
# 2      17.849098  15.912360      25.603904          Methane (CH4)
# 3      10.348395  16.897353      18.131688  Nitrogen oxides (NOX)
# 4      13.803120   6.435358      22.215066  Nitrogen oxides (NOX)
#
#    reportingYear  targetRelease
# 0           2015            AIR
# 1           2011            AIR
# 2           2011            AIR
# 3           2014            AIR
# 4           2012            AIR
#
# [5 rows x 24 columns]

# %%
train5.shape
# Out:
# (9501, 24)

# %%
train5.columns
# Out:
# Index(['', 'CITY ID', 'CONTINENT', 'City', 'DAY', 'DAY WITH FOGS',
#        'EPRTRAnnexIMainActivityCode', 'EPRTRAnnexIMainActivityLabel',
#        'EPRTRSectorCode', 'FacilityInspireID', 'MONTH', 'REPORTER NAME',
#        'avg_temp', 'avg_wind_speed', 'countryName', 'eprtrSectorName',
#        'facilityName', 'max_temp', 'max_wind_speed', 'min_temp',
#        'min_wind_speed', 'pollutant', 'reportingYear', 'targetRelease'],
#       dtype='object')

# %%
data_types = train5.dtypes
data_types
# Out:
#                                   int64
# CITY ID                          object
# CONTINENT                        object
# City                             object
# DAY                               int64
# DAY WITH FOGS                     int64
# EPRTRAnnexIMainActivityCode      object
# EPRTRAnnexIMainActivityLabel     object
# EPRTRSectorCode                   int64
# FacilityInspireID                object
# MONTH                             int64
# REPORTER NAME                    object
# avg_temp                        float64
# avg_wind_speed                  float64
# countryName                      object
# eprtrSectorName                  object
# facilityName                     object
# max_temp                        float64
# max_wind_speed                  float64
# min_temp                        float64
# min_wind_speed                  float64
# pollutant                        object
# reportingYear                     int64
# targetRelease                    object
# dtype: object

# %% [markdown]
# ###### Comparando json y CSV

# %% [markdown]
# Despreciamos las columnas de los archivos json que no se encuentran en los archivos csv.
# Una de ellas es ' ', y las otras dos son 'EPRTRSectorCode' y 'EPRTRAnnexIMainActivityCode'.

# %%
train3 = train3.drop(['','EPRTRSectorCode','EPRTRAnnexIMainActivityCode'], axis=1)
train4 = train4.drop(['','EPRTRSectorCode','EPRTRAnnexIMainActivityCode'], axis=1)
train5 = train5.drop(['','EPRTRSectorCode','EPRTRAnnexIMainActivityCode'], axis=1)
train3.shape, train4.shape, train5.shape
# Out:
# ((9500, 21), (9500, 21), (9501, 21))

# %% [markdown]
# Queda verificado que todos los dataframes tienen las mismas columnas.

# %% [markdown]
# ##### Concatenado de dataframes.

# %% [markdown]
# Concatenamos los csv.

# %%
merged_1 = pd.concat([train1, train2], ignore_index=True)

# %%
train1.shape[0]+train2.shape[0]
# Out:
# 37127

# %%
merged_1.shape
# Out:
# (37127, 21)

# %% [markdown]
# Concatenamos los json.

# %%
merged_2 = pd.concat([train3, train4, train5], ignore_index=True)

# %%
train3.shape[0]+train4.shape[0]+train5.shape[0]
# Out:
# 28501

# %% [markdown]
# ##### Concatenación de los csv y json final:

# %%
final_df = pd.concat([merged_1, merged_2], ignore_index=True)

# %%
final_df.head(2)
# Out:
#   countryName   eprtrSectorName  \
# 0     Germany  Mineral industry
# 1       Italy  Mineral industry
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0  Installations for the production of cement cli...
# 1  Installations for the production of cement cli...
#
#                                    FacilityInspireID  \
# 0  https://registry.gdi-de.org/id/de.ni.mu/062217...
# 1                         IT.CAED/240602021.FACILITY
#
#                            facilityName                  City targetRelease  \
# 0  Holcim (Deutschland) GmbH Werk Höver                Sehnde           AIR
# 1  Stabilimento di Tavernola Bergamasca  TAVERNOLA BERGAMASCA           AIR
#
#                pollutant  reportingYear  MONTH  ...  CONTINENT max_wind_speed  \
# 0   Carbon dioxide (CO2)           2015     10  ...     EUROPE      15.118767
# 1  Nitrogen oxides (NOX)           2018      9  ...     EUROPE      19.661550
#
#    avg_wind_speed  min_wind_speed  max_temp  avg_temp   min_temp  \
# 0       14.312541       21.419106  2.864895  4.924169   9.688206
# 1       19.368166       21.756389  5.462839  7.864403  12.023521
#
#    DAY WITH FOGS     REPORTER NAME                           CITY ID
# 0              2  Mr. Jacob Ortega  7cdb5e74adcb2ffaa21c1b61395a984f
# 1              1    Ashlee Serrano  cd1dbabbdba230b828c657a9b19a8963
#
# [2 rows x 21 columns]

# %%
final_df.shape
# Out:
# (65628, 21)

# %%
merged_1.shape[0]+merged_2.shape[0]
# Out:
# 65628

# %% [markdown]
# Queda verificado el que la recopilación de datasets ha sido exitosa.

# %% [markdown]
# ### ✅  3) Adaptar la información, identificar y corregir anomalías 🔧

# %%
print('El tramaño del dataframe:', final_df.shape)
# Out:
# El tramaño del dataframe: (65628, 21)

# %%
final_df['City'].nunique(), final_df['countryName'].nunique(), final_df['CONTINENT'].nunique(), final_df['EPRTRAnnexIMainActivityLabel'].nunique(), final_df['pollutant'].nunique(), final_df['targetRelease'].nunique()
# Out:
# (5136, 32, 1, 71, 3, 1)

# %% [markdown]
# * Eliminamos columnas que no aportan información al modelo predictivo.

# %%
final_cleaned_df = final_df.drop(['eprtrSectorName','City','DAY', 'FacilityInspireID','facilityName', 'CITY ID', 'REPORTER NAME', 'CONTINENT', 'targetRelease'], axis=1)

# %% [markdown]
# Ordenamiento de columnas:

# %%
final_cleaned_df = final_cleaned_df[['countryName', 'EPRTRAnnexIMainActivityLabel','reportingYear', 'MONTH', 'max_wind_speed', 'avg_wind_speed',
       'min_wind_speed', 'max_temp', 'avg_temp', 'min_temp', 'DAY WITH FOGS','pollutant']]

# %%
final_cleaned_df
# Out:
#           countryName                       EPRTRAnnexIMainActivityLabel  \
# 0             Germany  Installations for the production of cement cli...
# 1               Italy  Installations for the production of cement cli...
# 2               Spain  Landfills (excluding landfills of inert waste ...
# 3             Czechia  Thermal power stations and other combustion in...
# 4             Finland                 Urban waste-water treatment plants
# ...               ...                                                ...
# 65623          Cyprus  Thermal power stations and other combustion in...
# 65624         Finland  Thermal power stations and other combustion in...
# 65625        Slovenia  Landfills (excluding landfills of inert waste ...
# 65626           Italy          Underground mining and related operations
# 65627  United Kingdom  Thermal power stations and other combustion in...
#
#        reportingYear  MONTH  max_wind_speed  avg_wind_speed  min_wind_speed  \
# 0               2015     10       15.118767       14.312541       21.419106
# 1               2018      9       19.661550       19.368166       21.756389
# 2               2019      2       12.729453       14.701985       17.103930
# 3               2012      8       11.856417       16.122584       17.537184
# 4               2018     12       17.111930       20.201604       21.536012
# ...              ...    ...             ...             ...             ...
# 65623           2008      1       13.475988       18.556476       22.852530
# 65624           2008     12        8.815939       14.461703       20.553781
# 65625           2010      8       14.793298       16.688049       20.411498
# 65626           2014      1       14.911317       16.144091       22.647192
# 65627           2008      7       21.761812       21.296949       29.248276
#
#         max_temp   avg_temp   min_temp  DAY WITH FOGS              pollutant
# 0       2.864895   4.924169   9.688206              2   Carbon dioxide (CO2)
# 1       5.462839   7.864403  12.023521              1  Nitrogen oxides (NOX)
# 2       1.511201   4.233438   8.632193              2          Methane (CH4)
# 3      10.970301  10.298348  15.179215              0  Nitrogen oxides (NOX)
# 4      11.772039  11.344078  16.039004              2          Methane (CH4)
# ...          ...        ...        ...            ...                    ...
# 65623  13.345801  12.410783  17.148327              0   Carbon dioxide (CO2)
# 65624   3.820281   3.763833   5.657107              0  Nitrogen oxides (NOX)
# 65625  17.285365  18.349798  21.538441              2          Methane (CH4)
# 65626   6.387199   6.176238   9.269076              0  Nitrogen oxides (NOX)
# 65627   8.220678  11.194308  14.171780             13   Carbon dioxide (CO2)
#
# [65628 rows x 12 columns]

# %% [markdown]
# #### Dumizado de variables strings

# %%
to_regression_df = pd.get_dummies(final_cleaned_df, columns = ["countryName", "EPRTRAnnexIMainActivityLabel"])
to_regression_df.shape
# Out:
# (65628, 113)

# %%
to_regression_df.columns
# Out:
# Index(['reportingYear', 'MONTH', 'max_wind_speed', 'avg_wind_speed',
#        'min_wind_speed', 'max_temp', 'avg_temp', 'min_temp', 'DAY WITH FOGS',
#        'pollutant',
#        ...
#        'EPRTRAnnexIMainActivityLabel_Opencast mining and quarrying',
#        'EPRTRAnnexIMainActivityLabel_Plants for the pre-treatment (operations such as washing, bleaching, mercerisation) or dyeing of fibres or textiles',
#        'EPRTRAnnexIMainActivityLabel_Slaughterhouses',
#        'EPRTRAnnexIMainActivityLabel_Thermal power stations and other combustion installations',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from animal raw materials (other than milk)',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from vegetable raw materials',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products. Note to reporters, use Level 3 activity e.g. 8(b)(i), in preference to 8(b). Level 2 activity class (i.e. 8(b)) only to be used where Level 3 is not available.',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing of milk',
#        'EPRTRAnnexIMainActivityLabel_Underground mining and related operations',
#        'EPRTRAnnexIMainActivityLabel_Urban waste-water treatment plants'],
#       dtype='object', length=113)

# %%
a = to_regression_df.drop("pollutant", 1)
b = to_regression_df["pollutant"]
to_regression_df = pd.concat([a, b], axis = 1)
# Out:
# C:\Users\Kevin\AppData\Local\Temp/ipykernel_17296/2050544172.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   a = to_regression_df.drop("pollutant", 1)

# %%
to_regression_df["reportingYear"].dtypes
# Out:
# dtype('int64')

# %%
to_regression_df["reportingYear"].unique()
# Out:
# array([2015, 2018, 2019, 2012, 2009, 2008, 2011, 2010, 2014, 2007, 2013,
#        2020, 2017, 2016], dtype=int64)

# %%
#options = ['2018', '2019', '2020']
# selecting rows based on condition
#rslt_df = to_regression_df[to_regression_df['reportingYear'].isin(options)]

# %% [markdown]
# Reducimos los años los últimos 5 debido a la significancia.

# %%
rslt_df = to_regression_df.loc[to_regression_df['reportingYear'] > 2017]

# %%
rslt_df
# Out:
#        reportingYear  MONTH  max_wind_speed  avg_wind_speed  min_wind_speed  \
# 1               2018      9       19.661550       19.368166       21.756389
# 2               2019      2       12.729453       14.701985       17.103930
# 4               2018     12       17.111930       20.201604       21.536012
# 16              2019     10       17.372650       21.233404       26.990536
# 22              2020     12       14.560787       19.756882       26.527352
# ...              ...    ...             ...             ...             ...
# 65605           2019      2       13.039342       18.552725       22.751219
# 65607           2019      8       14.305154       17.365662       23.483116
# 65609           2019      5       13.455450       19.167535       26.057359
# 65615           2019      9       15.342608       19.904351       25.609210
# 65622           2019      8       15.719701       16.408202       22.311666
#
#         max_temp   avg_temp   min_temp  DAY WITH FOGS  countryName_Austria  \
# 1       5.462839   7.864403  12.023521              1                    0
# 2       1.511201   4.233438   8.632193              2                    0
# 4      11.772039  11.344078  16.039004              2                    0
# 16      1.139056   1.608550   3.286132              0                    0
# 22      5.205154   6.152162   8.633767              0                    0
# ...          ...        ...        ...            ...                  ...
# 65605  11.946200  13.200837  16.946812              2                    0
# 65607  16.861130  17.071693  20.845917              1                    0
# 65609  15.463125  14.537649  16.807429              0                    0
# 65615  10.374721  10.672463  14.706003              0                    0
# 65622  10.650435  11.022683  15.825824              2                    0
#
#        ...  \
# 1      ...
# 2      ...
# 4      ...
# 16     ...
# 22     ...
# ...    ...
# 65605  ...
# 65607  ...
# 65609  ...
# 65615  ...
# 65622  ...
#
#        EPRTRAnnexIMainActivityLabel_Plants for the pre-treatment (operations such as washing, bleaching, mercerisation) or dyeing of fibres or textiles  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Slaughterhouses  \
# 1                                                 0
# 2                                                 0
# 4                                                 0
# 16                                                0
# 22                                                0
# ...                                             ...
# 65605                                             0
# 65607                                             0
# 65609                                             0
# 65615                                             0
# 65622                                             0
#
#        EPRTRAnnexIMainActivityLabel_Thermal power stations and other combustion installations  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     1
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  1
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from animal raw materials (other than milk)  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from vegetable raw materials  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products. Note to reporters, use Level 3 activity e.g. 8(b)(i), in preference to 8(b). Level 2 activity class (i.e. 8(b)) only to be used where Level 3 is not available.  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Treatment and processing of milk  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Underground mining and related operations  \
# 1                                                      0
# 2                                                      0
# 4                                                      0
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  1
# 65615                                                  0
# 65622                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Urban waste-water treatment plants  \
# 1                                                      0
# 2                                                      0
# 4                                                      1
# 16                                                     0
# 22                                                     0
# ...                                                  ...
# 65605                                                  0
# 65607                                                  0
# 65609                                                  0
# 65615                                                  0
# 65622                                                  0
#
#                    pollutant
# 1      Nitrogen oxides (NOX)
# 2              Methane (CH4)
# 4              Methane (CH4)
# 16             Methane (CH4)
# 22      Carbon dioxide (CO2)
# ...                      ...
# 65605          Methane (CH4)
# 65607          Methane (CH4)
# 65609          Methane (CH4)
# 65615  Nitrogen oxides (NOX)
# 65622  Nitrogen oxides (NOX)
#
# [10168 rows x 113 columns]

# %% [markdown]
# ### ✅  4) Preparar datos para training y testing 🏃‍♂️

# %% [markdown]
# Normalización de los datos si están muy dispersos
# * df_norm = (df-df.min())/(df.max()-df.min())
# * df_norm.head()

# %%
#Importamos librería para dividir aleatoriamente entre training y testing
from sklearn.model_selection import train_test_split

# %%
#Asignación de variables predictoras y target
X = rslt_df.iloc[:,1:112]
Y = rslt_df.iloc[:,112:113]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state = 4)
print("Longitud de datos de entrenamiento: %s" %(len(X_train)), "longitud datos de testing: %s" %(len(X_test)))
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# Longitud de datos de entrenamiento: 8134 longitud datos de testing: 2034
# ((8134, 111), (2034, 111), (8134, 1), (2034, 1))

# %% [markdown]
# ### ✅ 5) Entrenar el modelo con los datos de entrenamiento🏋️‍♀️

# %% [markdown]
# #### Opción A.1: Logistic Regression para Clasificación

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.feature_selection import RFE

# %%
lgrclassif = LogisticRegression(max_iter=5000)
lgrclassif.fit(X_train,y_train.values.ravel())
y_pred_lgr = lgrclassif.predict(X_test)

# %%
lgrclassif.score(X_test, y_test)
# Out:
# 0.6007866273352999

# %% [markdown]
# #### Opción A.2: Logistic Regression para Clasificación Estandarizada

# %%
###Normalización con minmax.

# %%
rslt_df.columns
# Out:
# Index(['reportingYear', 'MONTH', 'max_wind_speed', 'avg_wind_speed',
#        'min_wind_speed', 'max_temp', 'avg_temp', 'min_temp', 'DAY WITH FOGS',
#        'countryName_Austria',
#        ...
#        'EPRTRAnnexIMainActivityLabel_Plants for the pre-treatment (operations such as washing, bleaching, mercerisation) or dyeing of fibres or textiles',
#        'EPRTRAnnexIMainActivityLabel_Slaughterhouses',
#        'EPRTRAnnexIMainActivityLabel_Thermal power stations and other combustion installations',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from animal raw materials (other than milk)',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products from vegetable raw materials',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing intended for the production of food and beverage products. Note to reporters, use Level 3 activity e.g. 8(b)(i), in preference to 8(b). Level 2 activity class (i.e. 8(b)) only to be used where Level 3 is not available.',
#        'EPRTRAnnexIMainActivityLabel_Treatment and processing of milk',
#        'EPRTRAnnexIMainActivityLabel_Underground mining and related operations',
#        'EPRTRAnnexIMainActivityLabel_Urban waste-water treatment plants',
#        'pollutant'],
#       dtype='object', length=113)

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()
rslt_minmax_df = pd.DataFrame(mmscaler.fit_transform(rslt_df[['max_wind_speed', 'avg_wind_speed',
       'min_wind_speed', 'max_temp', 'avg_temp', 'min_temp']]))

# %%
rslt_minmax_df.rename(columns = {0:'std_max_wind_speed', 1:'std_avg_wind_speed', 2:'std_min_wind_speed', 3:'std_max_temp', 4:'std_avg_temp', 5:'std_min_temp'}, inplace = True)

# %%
rslt_minmax_df
# Out:
#        std_max_wind_speed  std_avg_wind_speed  std_min_wind_speed  \
# 0                0.781405            0.671196            0.453690
# 1                0.313049            0.087760            0.139167
# 2                0.609144            0.775405            0.438792
# 3                0.626759            0.904416            0.807538
# 4                0.436780            0.719799            0.776225
# ...                   ...                 ...                 ...
# 10163            0.333986            0.569237            0.520945
# 10164            0.419509            0.420813            0.570424
# 10165            0.362100            0.646110            0.744452
# 10166            0.489603            0.738238            0.714155
# 10167            0.515080            0.301097            0.491229
#
#        std_max_temp  std_avg_temp  std_min_temp
# 0          0.349886      0.399056      0.460543
# 1          0.183749      0.219245      0.317970
# 2          0.615140      0.571375      0.629355
# 3          0.168103      0.089256      0.093220
# 4          0.339052      0.314263      0.318036
# ...             ...           ...           ...
# 10163      0.622462      0.663324      0.667519
# 10164      0.829098      0.855015      0.831439
# 10165      0.770322      0.729525      0.661660
# 10166      0.556393      0.538115      0.573315
# 10167      0.567985      0.555459      0.620393
#
# [10168 rows x 6 columns]

# %%
final_cleaned_df = rslt_df.drop(['max_wind_speed', 'avg_wind_speed',
       'min_wind_speed', 'max_temp', 'avg_temp', 'min_temp'], axis=1) #Extraeimos columnas normalizadas

# %%
final_cleaned_df.reset_index(drop=True, inplace=True)

# %%
rslt_minmax_df.reset_index(drop=True, inplace=True)

# %%
final_cleaned_std_df = pd.concat([final_cleaned_df, rslt_minmax_df], axis=1)

# %%
final_cleaned_std_df
# Out:
#        reportingYear  MONTH  DAY WITH FOGS  countryName_Austria  \
# 0               2018      9              1                    0
# 1               2019      2              2                    0
# 2               2018     12              2                    0
# 3               2019     10              0                    0
# 4               2020     12              0                    0
# ...              ...    ...            ...                  ...
# 10163           2019      2              2                    0
# 10164           2019      8              1                    0
# 10165           2019      5              0                    0
# 10166           2019      9              0                    0
# 10167           2019      8              2                    0
#
#        countryName_Belgium  countryName_Bulgaria  countryName_Croatia  \
# 0                        0                     0                    0
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    0
# 4                        0                     0                    0
# ...                    ...                   ...                  ...
# 10163                    0                     0                    0
# 10164                    0                     0                    0
# 10165                    0                     0                    0
# 10166                    0                     0                    0
# 10167                    0                     0                    0
#
#        countryName_Cyprus  countryName_Czechia  countryName_Denmark  ...  \
# 0                       0                    0                    0  ...
# 1                       0                    0                    0  ...
# 2                       0                    0                    0  ...
# 3                       0                    0                    0  ...
# 4                       0                    0                    0  ...
# ...                   ...                  ...                  ...  ...
# 10163                   0                    0                    0  ...
# 10164                   0                    0                    0  ...
# 10165                   0                    0                    0  ...
# 10166                   0                    0                    0  ...
# 10167                   0                    0                    0  ...
#
#        EPRTRAnnexIMainActivityLabel_Treatment and processing of milk  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 10163                                                  0
# 10164                                                  0
# 10165                                                  0
# 10166                                                  0
# 10167                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Underground mining and related operations  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 10163                                                  0
# 10164                                                  0
# 10165                                                  1
# 10166                                                  0
# 10167                                                  0
#
#        EPRTRAnnexIMainActivityLabel_Urban waste-water treatment plants  \
# 0                                                      0
# 1                                                      0
# 2                                                      1
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 10163                                                  0
# 10164                                                  0
# 10165                                                  0
# 10166                                                  0
# 10167                                                  0
#
#                    pollutant  std_max_wind_speed  std_avg_wind_speed  \
# 0      Nitrogen oxides (NOX)            0.781405            0.671196
# 1              Methane (CH4)            0.313049            0.087760
# 2              Methane (CH4)            0.609144            0.775405
# 3              Methane (CH4)            0.626759            0.904416
# 4       Carbon dioxide (CO2)            0.436780            0.719799
# ...                      ...                 ...                 ...
# 10163          Methane (CH4)            0.333986            0.569237
# 10164          Methane (CH4)            0.419509            0.420813
# 10165          Methane (CH4)            0.362100            0.646110
# 10166  Nitrogen oxides (NOX)            0.489603            0.738238
# 10167  Nitrogen oxides (NOX)            0.515080            0.301097
#
#        std_min_wind_speed  std_max_temp  std_avg_temp  std_min_temp
# 0                0.453690      0.349886      0.399056      0.460543
# 1                0.139167      0.183749      0.219245      0.317970
# 2                0.438792      0.615140      0.571375      0.629355
# 3                0.807538      0.168103      0.089256      0.093220
# 4                0.776225      0.339052      0.314263      0.318036
# ...                   ...           ...           ...           ...
# 10163            0.520945      0.622462      0.663324      0.667519
# 10164            0.570424      0.829098      0.855015      0.831439
# 10165            0.744452      0.770322      0.729525      0.661660
# 10166            0.714155      0.556393      0.538115      0.573315
# 10167            0.491229      0.567985      0.555459      0.620393
#
# [10168 rows x 113 columns]

# %%
a = final_cleaned_std_df.drop("pollutant", 1)
b = final_cleaned_std_df["pollutant"]
final_cleaned_std_df = pd.concat([a, b], axis = 1)
# Out:
# C:\Users\Kevin\AppData\Local\Temp/ipykernel_17296/4208609729.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   a = final_cleaned_std_df.drop("pollutant", 1)

# %%
X = final_cleaned_std_df.iloc[:,1:112]
Y = final_cleaned_std_df.iloc[:,112:113]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.40, random_state = 4)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6100, 111), (4068, 111), (6100, 1), (4068, 1))

# %%
lgrclassif = LogisticRegression(max_iter=5000)
lgrclassif.fit(X_train,y_train.values.ravel())
y_pred_lgr = lgrclassif.predict(X_test)

# %%
lgrclassif.fit(X_train,y_train.values.ravel())
y_pred_lgr = lgrclassif.predict(X_test)

# %%
lgrclassif.score(X_test, y_test)
# Out:
# 0.6049655850540806

# %% [markdown]
# #### Opción B: Random Forest para Clasificación

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_jobs=2, oob_score=True, n_estimators=500)
forest.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(n_estimators=500, n_jobs=2, oob_score=True)

# %%
forest.oob_score_
# Out:
# 0.6573770491803279

# %% [markdown]
# ### ✅ 6) Hacer predicciones con los datos de prueba 🤔

# %%
df_test = pd.read_csv("../../Practice/3- Schneider Hackathon/Datasets/test_x.csv")

# %%
df_test.head()
# Out:
#    test_index  countryName  EPRTRSectorCode                  eprtrSectorName  \
# 0           0       Poland                3                 Mineral industry
# 1           1   Luxembourg                5  Waste and wastewater management
# 2           2  Netherlands                1                    Energy sector
# 3           3       Sweden                5  Waste and wastewater management
# 4           4     Portugal                1                    Energy sector
#
#   EPRTRAnnexIMainActivityCode  \
# 0                        3(a)
# 1                        5(d)
# 2                        1(c)
# 3                        5(d)
# 4                        1(c)
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0          Underground mining and related operations
# 1  Landfills (excluding landfills of inert waste ...
# 2  Thermal power stations and other combustion in...
# 3  Landfills (excluding landfills of inert waste ...
# 4  Thermal power stations and other combustion in...
#
#             FacilityInspireID  \
# 0    PL.MŚ/000002357.FACILITY
# 1  LU.CAED/000012000.FACILITY
# 2      NL.EEA/212857.FACILITY
# 3   SE.CAED/10013901.Facility
# 4      PT.EEA/133926.FACILITY
#
#                                         facilityName       City targetRelease  \
# 0  Polska Grupa Górnicza sp. z o.o. Oddział KWK R...  Rydułtowy           AIR
# 1                                              Sidec   Diekirch           AIR
# 2               Nuon Power Generation BV (Eemshaven)  Eemshaven           AIR
# 3                       HÖGBYTORPS AVFALLSANLÄGGNING        BRO           AIR
# 4  SPCG - Sociedade Portuguesa de Co-Geração Eléc...    SETÚBAL           AIR
#
#    ...  CONTINENT  max_wind_speed  avg_wind_speed min_wind_speed   max_temp  \
# 0  ...     EUROPE       14.080054       14.855940      18.474836  10.278561
# 1  ...     EUROPE       16.052425       17.623877      22.622900   6.625910
# 2  ...     EUROPE       13.647318       15.541979      17.818521   5.669436
# 3  ...     EUROPE       16.336762       17.458113      19.961777   6.160560
# 4  ...     EUROPE       21.516602       20.532473      21.617137  10.964012
#
#     avg_temp   min_temp  DAY WITH FOGS     REPORTER NAME  \
# 0  11.381181  13.480752              1     Brittany Buck
# 1   8.840137  13.422924              0     Lauren Fisher
# 2   8.403322  11.276388              2    Linda Thompson
# 3   7.571596   9.443572              2  Bethany Mcmillan
# 4  11.548033  12.624114              2     Sarah Hoffman
#
#                             CITY ID
# 0  826b1de9dad293ae3e4f9cbaf6cf3420
# 1  ed30a6667b40ba0a66198b3173e7353f
# 2  78e1082c3cfef3bdf3554da8d6afcc34
# 3  27f959641950d381869d746d7d0e7d4e
# 4  1cb71655d9e0bd5cedb2320bf5fdd8f7
#
# [5 rows x 23 columns]

# %% [markdown]
# Ajustando los parámetros de X_test.

# %% [markdown]
# ## Sentimos no haber llegado más lejos.
# ## Nos hemos quedado solos en nuestros respectivos equipos previstos.
# ## Los mentores nos han presentado a las 12:00hs.
# ## En la próxima ocasión lo haremos mejor.
# ## Gracias por todo!!!
